# %%
import pandas as pd
import seaborn as sns
import collections
from collections import Counter

# %%
path = './data/Table_S1.txt'
df = pd.read_csv(path, sep='\t')
# Out:
# /Users/jonathanlifferth/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3251: DtypeWarning: Columns (53) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.shape
# Out:
# (55844, 73)

# %%
cols = df.columns
for i, col in enumerate(cols):
    print(i, col)
# Out:
# 0 donor_unique_id
# 1 Chr
# 2 Start
# 3 End
# 4 Intrchr. SVs
# 5 Total SVs (intrachr. + transl.)
# 6 SVs in sample
# 7 Nb. DEL
# 8 Nb. DUP
# 9 Nb. h2hINV
# 10 Nb. t2tINV
# 11 Nb. TRA
# 12 P fragment joints
# 13 P chr breakpoint enrichment
# 14 Nb. CN segments
# 15 P exponential dist
# 16 P exponential dist. cluster
# 17 CN segments
# 18 Nb. oscillating CN
# 19 Nb. oscillaring CN 3 states
# 20 CN segments chr.
# 21 Nb. oscillating chr.
# 22 Nb. oscillating chr 3 states
# 23 PGA sample
# 24 PGA chr.
# 25 PGNA chr.
# 26 clustered APOBEC mutations (<2.5 Kb)
# 27 CN mode 1
# 28 CN mode 2
# 29 wgs_exclusion_white_gray
# 30 dcc_project_code
# 31 Other interacting chromothripsis regions
# 32 FDR fragment joints intrachr. SVs and TRA
# 33 FDR chr breakpoint enrichment
# 34 FDR exponential dist.
# 35 FDR exponential dist. cluster
# 36 FDR fragment joints intrachr. SVs
# 37 chromo
# 38 chromo_label
# 39 tissue.x
# 40 donor_idx
# 41 tissue2
# 42 purity
# 43 ploidy
# 44 histo
# 45 type_chromothripsis
# 46 Nb. breakpoints in chromosome
# 47 Fraction SVs in chromothripsis
# 48 TP53_mutations
# 49 MDM2_CN
# 50 project_code
# 51 icgc_donor_id
# 52 submitted_donor_id
# 53 tcga_donor_uuid
# 54 donor_sex
# 55 donor_vital_status
# 56 donor_diagnosis_icd10
# 57 first_therapy_type
# 58 first_therapy_response
# 59 donor_age_at_diagnosis
# 60 donor_survival_time
# 61 donor_interval_of_last_followup
# 62 tobacco_smoking_history_indicator
# 63 tobacco_smoking_intensity
# 64 alcohol_history
# 65 alcohol_history_intensity
# 66 donor_wgs_included_excluded
# 67 histology_abbreviation
# 68 tissue.y
# 69 code
# 70 event
# 71 response
# 72 comment

# %%
df.head()
# Out:
#                                  donor_unique_id Chr        Start  \
# 0  BLCA-US::096b4f32-10c1-4737-a0dd-cae04c54ee33   1   33384961.0
# 1  BLCA-US::096b4f32-10c1-4737-a0dd-cae04c54ee33   2  123278460.0
# 2  BLCA-US::096b4f32-10c1-4737-a0dd-cae04c54ee33   3   31044413.0
# 3  BLCA-US::096b4f32-10c1-4737-a0dd-cae04c54ee33   4  176301814.0
# 4  BLCA-US::096b4f32-10c1-4737-a0dd-cae04c54ee33   5   67743249.0
#
#            End  Intrchr. SVs  Total SVs (intrachr. + transl.)  SVs in sample  \
# 0  151855802.0             2                                3            136
# 1  153873571.0             4                                4            136
# 2   84685234.0            12                               12            136
# 3  177594189.0             2                                2            136
# 4  176695147.0            14                               14            136
#
#    Nb. DEL  Nb. DUP  Nb. h2hINV  ...  tobacco_smoking_intensity  \
# 0        0        0           0  ...                        NaN
# 1        2        0           1  ...                        NaN
# 2        2        2           4  ...                        NaN
# 3        0        0           1  ...                        NaN
# 4        2        4           5  ...                        NaN
#
#    alcohol_history  alcohol_history_intensity  donor_wgs_included_excluded  \
# 0              NaN                        NaN                     Included
# 1              NaN                        NaN                     Included
# 2              NaN                        NaN                     Included
# 3              NaN                        NaN                     Included
# 4              NaN                        NaN                     Included
#
#    histology_abbreviation  tissue.y  code  event  response  comment
# 0             Bladder-TCC      BLCA    US      1      14.9      NaN
# 1             Bladder-TCC      BLCA    US      1      14.9      NaN
# 2             Bladder-TCC      BLCA    US      1      14.9      NaN
# 3             Bladder-TCC      BLCA    US      1      14.9      NaN
# 4             Bladder-TCC      BLCA    US      1      14.9      NaN
#
# [5 rows x 73 columns]

# %% [markdown]
# ## Frequency of tumor type (histology_abbreviation)

# %%
Counter(df[cols[67]])
# Out:
# Counter({'Bladder-TCC': 529,
#          'Bone-Osteosarc': 782,
#          'Bone-Benign': 299,
#          'Bone-Epith': 230,
#          'Breast-AdenoCA': 4370,
#          'Breast-LobularCA': 299,
#          'Breast-DCIS': 69,
#          'Biliary-AdenoCA': 759,
#          'Cervix-SCC': 414,
#          'Cervix-AdenoCA': 46,
#          'Lymph-CLL': 1978,
#          'Myeloid-MPN': 161,
#          'Myeloid-MDS': 23,
#          'ColoRect-AdenoCA': 1196,
#          'Lymph-BNHL': 2415,
#          'Prost-AdenoCA': 4301,
#          'Eso-AdenoCA': 1978,
#          'Stomach-AdenoCA': 1518,
#          'CNS-GBM': 874,
#          'Head-SCC': 1265,
#          'Kidney-ChRCC': 897,
#          'Kidney-RCC': 3059,
#          'Myeloid-AML': 184,
#          'CNS-Oligo': 391,
#          'Liver-HCC': 7153,
#          'Lung-AdenoCA': 828,
#          'Lung-SCC': 1081,
#          'Skin-Melanoma': 2438,
#          'Ovary-AdenoCA': 2507,
#          'Panc-AdenoCA': 5244,
#          'Panc-Endocrine': 1564,
#          'CNS-Medullo': 2806,
#          'CNS-PiloAstro': 1794,
#          'SoftTissue-Leiomyo': 345,
#          'SoftTissue-Liposarc': 414,
#          'Thy-AdenoCA': 690,
#          'Uterus-AdenoCA': 943})

# %%
Nb_breakpoints_in_chromosome = dict(Counter(df[cols[46]]))
Nb_breakpoints_in_chromosome = dict(sorted(Nb_breakpoints_in_chromosome.items(), key=lambda item: item[1], reverse=True))
Nb_breakpoints_in_chromosome
# Out:
# {0: 29684,
#  2: 7618,
#  4: 5026,
#  6: 2377,
#  8: 1597,
#  10: 916,
#  5: 733,
#  12: 732,
#  7: 703,
#  9: 575,
#  14: 493,
#  11: 416,
#  13: 367,
#  16: 343,
#  3: 307,
#  18: 279,
#  15: 251,
#  20: 242,
#  17: 210,
#  19: 193,
#  22: 179,
#  24: 154,
#  21: 144,
#  26: 123,
#  23: 116,
#  28: 105,
#  25: 96,
#  27: 87,
#  30: 82,
#  31: 73,
#  32: 69,
#  38: 58,
#  33: 53,
#  34: 49,
#  29: 48,
#  42: 46,
#  36: 46,
#  35: 46,
#  40: 45,
#  37: 38,
#  39: 38,
#  48: 35,
#  43: 33,
#  44: 29,
#  41: 28,
#  52: 25,
#  50: 24,
#  45: 24,
#  46: 23,
#  49: 19,
#  64: 19,
#  47: 18,
#  56: 17,
#  60: 17,
#  88: 17,
#  58: 16,
#  57: 15,
#  55: 15,
#  68: 14,
#  78: 14,
#  51: 13,
#  53: 13,
#  54: 13,
#  59: 13,
#  61: 13,
#  66: 12,
#  76: 12,
#  80: 12,
#  82: 11,
#  99: 11,
#  71: 11,
#  70: 10,
#  79: 10,
#  84: 10,
#  69: 10,
#  86: 10,
#  115: 9,
#  62: 9,
#  75: 9,
#  67: 9,
#  72: 9,
#  83: 9,
#  89: 9,
#  128: 9,
#  96: 8,
#  65: 8,
#  63: 8,
#  77: 8,
#  90: 7,
#  98: 7,
#  81: 7,
#  85: 6,
#  133: 6,
#  109: 6,
#  100: 6,
#  92: 6,
#  104: 6,
#  93: 5,
#  94: 5,
#  97: 5,
#  120: 5,
#  117: 5,
#  106: 5,
#  95: 5,
#  87: 5,
#  110: 5,
#  129: 4,
#  101: 4,
#  127: 4,
#  91: 4,
#  145: 4,
#  122: 4,
#  108: 4,
#  148: 4,
#  172: 4,
#  102: 4,
#  132: 4,
#  105: 4,
#  162: 4,
#  154: 4,
#  166: 3,
#  186: 3,
#  143: 3,
#  136: 3,
#  116: 3,
#  416: 3,
#  158: 3,
#  111: 3,
#  204: 3,
#  144: 3,
#  123: 3,
#  238: 3,
#  160: 3,
#  126: 3,
#  138: 3,
#  149: 3,
#  103: 2,
#  185: 2,
#  142: 2,
#  147: 2,
#  155: 2,
#  112: 2,
#  119: 2,
#  139: 2,
#  151: 2,
#  188: 2,
#  198: 2,
#  178: 2,
#  171: 2,
#  137: 2,
#  202: 2,
#  135: 2,
#  157: 2,
#  164: 2,
#  176: 2,
#  265: 2,
#  283: 2,
#  140: 2,
#  113: 2,
#  401: 2,
#  73: 2,
#  206: 2,
#  181: 2,
#  218: 2,
#  968: 2,
#  177: 2,
#  233: 2,
#  183: 2,
#  170: 2,
#  161: 2,
#  130: 2,
#  179: 2,
#  118: 2,
#  262: 2,
#  121: 2,
#  114: 2,
#  900: 1,
#  225: 1,
#  349: 1,
#  152: 1,
#  131: 1,
#  187: 1,
#  125: 1,
#  200: 1,
#  490: 1,
#  345: 1,
#  327: 1,
#  316: 1,
#  201: 1,
#  194: 1,
#  190: 1,
#  242: 1,
#  214: 1,
#  216: 1,
#  361: 1,
#  74: 1,
#  343: 1,
#  520: 1,
#  230: 1,
#  261: 1,
#  299: 1,
#  221: 1,
#  197: 1,
#  605: 1,
#  174: 1,
#  124: 1,
#  336: 1,
#  335: 1,
#  429: 1,
#  184: 1,
#  209: 1,
#  356: 1,
#  250: 1,
#  189: 1,
#  163: 1,
#  322: 1,
#  260: 1,
#  173: 1,
#  1788: 1,
#  314: 1,
#  427: 1,
#  310: 1,
#  354: 1,
#  269: 1,
#  662: 1,
#  146: 1,
#  307: 1,
#  180: 1,
#  247: 1,
#  379: 1,
#  1417: 1,
#  282: 1,
#  134: 1,
#  195: 1,
#  400: 1,
#  268: 1,
#  446: 1,
#  952: 1,
#  304: 1,
#  498: 1,
#  558: 1,
#  255: 1,
#  226: 1,
#  289: 1,
#  169: 1,
#  305: 1,
#  159: 1,
#  358: 1,
#  252: 1,
#  293: 1,
#  273: 1,
#  407: 1,
#  422: 1,
#  945: 1,
#  724: 1,
#  263: 1,
#  191: 1,
#  537: 1,
#  240: 1,
#  388: 1,
#  1824: 1,
#  236: 1,
#  389: 1,
#  1108: 1,
#  688: 1,
#  228: 1,
#  223: 1,
#  777: 1,
#  241: 1,
#  1322: 1,
#  793: 1,
#  497: 1,
#  861: 1,
#  770: 1,
#  691: 1,
#  603: 1,
#  193: 1,
#  549: 1,
#  248: 1,
#  318: 1,
#  820: 1,
#  540: 1,
#  231: 1,
#  486: 1,
#  107: 1,
#  272: 1,
#  167: 1}

# %%
keys = list(Nb_breakpoints_in_chromosome.keys())
values = list(Nb_breakpoints_in_chromosome.values())

Nb_breakpoints_in_chromosome_df = pd.DataFrame(list(zip(keys, values)))
Nb_breakpoints_in_chromosome_df[1:]
# Out:
#        0     1
# 1      2  7618
# 2      4  5026
# 3      6  2377
# 4      8  1597
# 5     10   916
# ..   ...   ...
# 282  231     1
# 283  486     1
# 284  107     1
# 285  272     1
# 286  167     1
#
# [286 rows x 2 columns]

# %%
sns.scatterplot(data=Nb_breakpoints_in_chromosome_df, x=0, y=1)
# Out:
# <AxesSubplot:xlabel='0', ylabel='1'>

# %%
sns.kdeplot(data=df[cols[46]])
# Out:
# <AxesSubplot:xlabel='Nb. breakpoints in chromosome', ylabel='Density'>

# %% [markdown]
# ## Identifying patient chromosome with highest number of breakpoints

# %%
df[cols[46]].max()
# Out:
# 1824

# %%
df[df[cols[46]] == 1824]
# Out:
#                                      donor_unique_id Chr      Start  \
# 51968  SARC-US::39f68467-3d37-4b19-aa43-ed7b120c619d  12  2301723.0
#
#                End  Intrchr. SVs  Total SVs (intrachr. + transl.)  \
# 51968  133385530.0           615                             1209
#
#        SVs in sample  Nb. DEL  Nb. DUP  Nb. h2hINV  ...  \
# 51968           1635      164      138         161  ...
#
#        tobacco_smoking_intensity  alcohol_history  alcohol_history_intensity  \
# 51968                        NaN              NaN                        NaN
#
#        donor_wgs_included_excluded  histology_abbreviation  tissue.y  code  \
# 51968                     Included     SoftTissue-Liposarc      SARC    US
#
#        event  response  comment
# 51968      1      9.05      NaN
#
# [1 rows x 73 columns]

# %%
df[df[cols[0]] == 'SARC-US::39f68467-3d37-4b19-aa43-ed7b120c619d']
# Out:
#                                      donor_unique_id Chr        Start  \
# 51957  SARC-US::39f68467-3d37-4b19-aa43-ed7b120c619d   1          NaN
# 51958  SARC-US::39f68467-3d37-4b19-aa43-ed7b120c619d   2          NaN
# 51959  SARC-US::39f68467-3d37-4b19-aa43-ed7b120c619d   3    4159559.0
# 51960  SARC-US::39f68467-3d37-4b19-aa43-ed7b120c619d   4  127090720.0
# 51961  SARC-US::39f68467-3d37-4b19-aa43-ed7b120c619d   5     492905.0
# 51962  SARC-US::39f68467-3d37-4b19-aa43-ed7b120c619d   6   29105248.0
# 51963  SARC-US::39f68467-3d37-4b19-aa43-ed7b120c619d   7   77961769.0
# 51964  SARC-US::39f68467-3d37-4b19-aa43-ed7b120c619d   8   36818890.0
# 51965  SARC-US::39f68467-3d37-4b19-aa43-ed7b120c619d   9  103346393.0
# 51966  SARC-US::39f68467-3d37-4b19-aa43-ed7b120c619d  10          NaN
# 51967  SARC-US::39f68467-3d37-4b19-aa43-ed7b120c619d  11          NaN
# 51968  SARC-US::39f68467-3d37-4b19-aa43-ed7b120c619d  12    2301723.0
# 51969  SARC-US::39f68467-3d37-4b19-aa43-ed7b120c619d  13          NaN
# 51970  SARC-US::39f68467-3d37-4b19-aa43-ed7b120c619d  14          NaN
# 51971  SARC-US::39f68467-3d37-4b19-aa43-ed7b120c619d  15          NaN
# 51972  SARC-US::39f68467-3d37-4b19-aa43-ed7b120c619d  16          NaN
# 51973  SARC-US::39f68467-3d37-4b19-aa43-ed7b120c619d  17          NaN
# 51974  SARC-US::39f68467-3d37-4b19-aa43-ed7b120c619d  18          NaN
# 51975  SARC-US::39f68467-3d37-4b19-aa43-ed7b120c619d  19   57077268.0
# 51976  SARC-US::39f68467-3d37-4b19-aa43-ed7b120c619d  20   33082736.0
# 51977  SARC-US::39f68467-3d37-4b19-aa43-ed7b120c619d  21          NaN
# 51978  SARC-US::39f68467-3d37-4b19-aa43-ed7b120c619d  22   23956086.0
# 51979  SARC-US::39f68467-3d37-4b19-aa43-ed7b120c619d   X   24105896.0
#
#                End  Intrchr. SVs  Total SVs (intrachr. + transl.)  \
# 51957          NaN             0                                0
# 51958          NaN             0                                0
# 51959   20777597.0            14                              107
# 51960  151907883.0            30                               49
# 51961   14929135.0            16                              100
# 51962  126918492.0            12                              206
# 51963  133784786.0             8                              121
# 51964   48127350.0             3                               74
# 51965  140789888.0            50                               78
# 51966          NaN             0                                0
# 51967          NaN             0                                0
# 51968  133385530.0           615                             1209
# 51969          NaN             0                                0
# 51970          NaN             0                                0
# 51971          NaN             0                                0
# 51972          NaN             0                                0
# 51973          NaN             0                                0
# 51974          NaN             0                                0
# 51975   57124768.0             1                                2
# 51976   57423558.0             8                               73
# 51977          NaN             0                                0
# 51978   48888566.0             4                               10
# 51979  100833756.0             3                                3
#
#        SVs in sample  Nb. DEL  Nb. DUP  Nb. h2hINV  ...  \
# 51957           1635        0        0           0  ...
# 51958           1635        0        0           0  ...
# 51959           1635        4        3           5  ...
# 51960           1635        4        8          11  ...
# 51961           1635        9        4           3  ...
# 51962           1635        3        3           3  ...
# 51963           1635        1        3           2  ...
# 51964           1635        1        0           1  ...
# 51965           1635        9       13          16  ...
# 51966           1635        0        0           0  ...
# 51967           1635        0        0           0  ...
# 51968           1635      164      138         161  ...
# 51969           1635        0        0           0  ...
# 51970           1635        0        0           0  ...
# 51971           1635        0        0           0  ...
# 51972           1635        0        0           0  ...
# 51973           1635        0        0           0  ...
# 51974           1635        0        0           0  ...
# 51975           1635        0        0           0  ...
# 51976           1635        4        0           3  ...
# 51977           1635        0        0           0  ...
# 51978           1635        0        2           1  ...
# 51979           1635        0        0           1  ...
#
#        tobacco_smoking_intensity  alcohol_history  alcohol_history_intensity  \
# 51957                        NaN              NaN                        NaN
# 51958                        NaN              NaN                        NaN
# 51959                        NaN              NaN                        NaN
# 51960                        NaN              NaN                        NaN
# 51961                        NaN              NaN                        NaN
# 51962                        NaN              NaN                        NaN
# 51963                        NaN              NaN                        NaN
# 51964                        NaN              NaN                        NaN
# 51965                        NaN              NaN                        NaN
# 51966                        NaN              NaN                        NaN
# 51967                        NaN              NaN                        NaN
# 51968                        NaN              NaN                        NaN
# 51969                        NaN              NaN                        NaN
# 51970                        NaN              NaN                        NaN
# 51971                        NaN              NaN                        NaN
# 51972                        NaN              NaN                        NaN
# 51973                        NaN              NaN                        NaN
# 51974                        NaN              NaN                        NaN
# 51975                        NaN              NaN                        NaN
# 51976                        NaN              NaN                        NaN
# 51977                        NaN              NaN                        NaN
# 51978                        NaN              NaN                        NaN
# 51979                        NaN              NaN                        NaN
#
#        donor_wgs_included_excluded  histology_abbreviation  tissue.y  code  \
# 51957                     Included     SoftTissue-Liposarc      SARC    US
# 51958                     Included     SoftTissue-Liposarc      SARC    US
# 51959                     Included     SoftTissue-Liposarc      SARC    US
# 51960                     Included     SoftTissue-Liposarc      SARC    US
# 51961                     Included     SoftTissue-Liposarc      SARC    US
# 51962                     Included     SoftTissue-Liposarc      SARC    US
# 51963                     Included     SoftTissue-Liposarc      SARC    US
# 51964                     Included     SoftTissue-Liposarc      SARC    US
# 51965                     Included     SoftTissue-Liposarc      SARC    US
# 51966                     Included     SoftTissue-Liposarc      SARC    US
# 51967                     Included     SoftTissue-Liposarc      SARC    US
# 51968                     Included     SoftTissue-Liposarc      SARC    US
# 51969                     Included     SoftTissue-Liposarc      SARC    US
# 51970                     Included     SoftTissue-Liposarc      SARC    US
# 51971                     Included     SoftTissue-Liposarc      SARC    US
# 51972                     Included     SoftTissue-Liposarc      SARC    US
# 51973                     Included     SoftTissue-Liposarc      SARC    US
# 51974                     Included     SoftTissue-Liposarc      SARC    US
# 51975                     Included     SoftTissue-Liposarc      SARC    US
# 51976                     Included     SoftTissue-Liposarc      SARC    US
# 51977                     Included     SoftTissue-Liposarc      SARC    US
# 51978                     Included     SoftTissue-Liposarc      SARC    US
# 51979                     Included     SoftTissue-Liposarc      SARC    US
#
#        event  response  comment
# 51957      1      9.05      NaN
# 51958      1      9.05      NaN
# 51959      1      9.05      NaN
# 51960      1      9.05      NaN
# 51961      1      9.05      NaN
# 51962      1      9.05      NaN
# 51963      1      9.05      NaN
# 51964      1      9.05      NaN
# 51965      1      9.05      NaN
# 51966      1      9.05      NaN
# 51967      1      9.05      NaN
# 51968      1      9.05      NaN
# 51969      1      9.05      NaN
# 51970      1      9.05      NaN
# 51971      1      9.05      NaN
# 51972      1      9.05      NaN
# 51973      1      9.05      NaN
# 51974      1      9.05      NaN
# 51975      1      9.05      NaN
# 51976      1      9.05      NaN
# 51977      1      9.05      NaN
# 51978      1      9.05      NaN
# 51979      1      9.05      NaN
#
# [23 rows x 73 columns]

# %% [markdown]
# ## Let's pull all data for Chr22 and see how we could train model parameters on these observations

# %%
df[cols[1]]
# Out:
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5
#          ..
# 55839    19
# 55840    20
# 55841    21
# 55842    22
# 55843     X
# Name: Chr, Length: 55844, dtype: object

# %%
chr22_df = df[df[cols[1]] == '22']

# %%
chr22_df.shape
# Out:
# (2428, 73)

# %%
chr22_df.head()
# Out:
#                                    donor_unique_id Chr       Start  \
# 21   BLCA-US::096b4f32-10c1-4737-a0dd-cae04c54ee33  22  19879249.0
# 44   BLCA-US::178b28cd-99c3-48dc-8d09-1ef71b4cee80  22         NaN
# 67   BLCA-US::1e308b12-0590-4dae-94d0-a539fcf25df7  22  40454454.0
# 90   BLCA-US::24f21425-b001-4986-aedf-5b4dd851c6ad  22  36244665.0
# 113  BLCA-US::3ed614e7-f356-4d87-985b-d3bbbae3bb40  22  19474849.0
#
#             End  Intrchr. SVs  Total SVs (intrachr. + transl.)  SVs in sample  \
# 21   36142675.0             1                                3            136
# 44          NaN             0                                0             59
# 67   48873957.0             1                                1             18
# 90   41958231.0             1                                4            271
# 113  40455649.0            10                               18            449
#
#      Nb. DEL  Nb. DUP  Nb. h2hINV  ...  tobacco_smoking_intensity  \
# 21         1        0           0  ...                        NaN
# 44         0        0           0  ...                        NaN
# 67         1        0           0  ...                        NaN
# 90         2        0           1  ...                        NaN
# 113        4        3           2  ...                        NaN
#
#      alcohol_history  alcohol_history_intensity  donor_wgs_included_excluded  \
# 21               NaN                        NaN                     Included
# 44               NaN                        NaN                     Included
# 67               NaN                        NaN                     Included
# 90               NaN                        NaN                     Included
# 113              NaN                        NaN                     Included
#
#      histology_abbreviation  tissue.y  code  event  response  comment
# 21              Bladder-TCC      BLCA    US      1     14.90      NaN
# 44              Bladder-TCC      BLCA    US      0      3.98      NaN
# 67              Bladder-TCC      BLCA    US      0      0.00      NaN
# 90              Bladder-TCC      BLCA    US      1      5.07      NaN
# 113             Bladder-TCC      BLCA    US      0      8.98      NaN
#
# [5 rows x 73 columns]

# %%
chr22_sv = chr22_df[chr22_df[cols[7]] > 0]
chr22_sv
# Out:
#                                      donor_unique_id Chr       Start  \
# 21     BLCA-US::096b4f32-10c1-4737-a0dd-cae04c54ee33  22  19879249.0
# 67     BLCA-US::1e308b12-0590-4dae-94d0-a539fcf25df7  22  40454454.0
# 90     BLCA-US::24f21425-b001-4986-aedf-5b4dd851c6ad  22  36244665.0
# 113    BLCA-US::3ed614e7-f356-4d87-985b-d3bbbae3bb40  22  19474849.0
# 320    BLCA-US::904a8757-e0c5-41ef-b583-c8f170caaac1  22  32991210.0
# ...                                              ...  ..         ...
# 55290  UCEC-US::944a102f-3475-45aa-9e30-4b92d1449f00  22  32093117.0
# 55313  UCEC-US::94817e78-78f5-4556-9394-610df65605e2  22  37989909.0
# 55359  UCEC-US::9aa8c2b4-db32-4899-bf0c-d578cb175e90  22  22585126.0
# 55589  UCEC-US::c88e3901-f3ee-436a-ba80-143c8eab7d69  22  19010244.0
# 55727  UCEC-US::e1e8dc66-467c-48a5-be56-3db4f665b9f1  22  23616561.0
#
#               End  Intrchr. SVs  Total SVs (intrachr. + transl.)  \
# 21     36142675.0             1                                3
# 67     48873957.0             1                                1
# 90     41958231.0             1                                4
# 113    40455649.0            10                               18
# 320    41707960.0             1                                4
# ...           ...           ...                              ...
# 55290  32660408.0            10                               10
# 55313  38043844.0             1                                1
# 55359  41923573.0             1                                3
# 55589  39040501.0             1                                9
# 55727  42631823.0             1                                4
#
#        SVs in sample  Nb. DEL  Nb. DUP  Nb. h2hINV  ...  \
# 21               136        1        0           0  ...
# 67                18        1        0           0  ...
# 90               271        2        0           1  ...
# 113              449        4        3           2  ...
# 320              274        1        1           0  ...
# ...              ...      ...      ...         ...  ...
# 55290            189        1        4           2  ...
# 55313            283        1        0           0  ...
# 55359            127        1        1           0  ...
# 55589            382        2        3           0  ...
# 55727            305        1        1           0  ...
#
#        tobacco_smoking_intensity  alcohol_history  alcohol_history_intensity  \
# 21                           NaN              NaN                        NaN
# 67                           NaN              NaN                        NaN
# 90                           NaN              NaN                        NaN
# 113                          NaN              NaN                        NaN
# 320                          NaN              NaN                        NaN
# ...                          ...              ...                        ...
# 55290                        NaN              NaN                        NaN
# 55313                        NaN              NaN                        NaN
# 55359                        NaN              NaN                        NaN
# 55589                        NaN              NaN                        NaN
# 55727                        NaN              NaN                        NaN
#
#        donor_wgs_included_excluded  histology_abbreviation  tissue.y  code  \
# 21                        Included             Bladder-TCC      BLCA    US
# 67                        Included             Bladder-TCC      BLCA    US
# 90                        Included             Bladder-TCC      BLCA    US
# 113                       Included             Bladder-TCC      BLCA    US
# 320                       Included             Bladder-TCC      BLCA    US
# ...                            ...                     ...       ...   ...
# 55290                     Included          Uterus-AdenoCA      UCEC    US
# 55313                     Included          Uterus-AdenoCA      UCEC    US
# 55359                     Included          Uterus-AdenoCA      UCEC    US
# 55589                     Included          Uterus-AdenoCA      UCEC    US
# 55727                     Included          Uterus-AdenoCA      UCEC    US
#
#        event  response  comment
# 21         1     14.90      NaN
# 67         0      0.00      NaN
# 90         1      5.07      NaN
# 113        0      8.98      NaN
# 320        1      2.14      NaN
# ...      ...       ...      ...
# 55290      0     31.05      NaN
# 55313      0     47.60      NaN
# 55359      1     48.82      NaN
# 55589      0     71.28      NaN
# 55727      0     85.59      NaN
#
# [374 rows x 73 columns]

# %%
breaks22 = dict(Counter(chr22_df[cols[46]]))
breaks22 = dict(sorted(breaks22.items()))
breaks22_df = pd.DataFrame(list(zip(breaks22.keys(), breaks22.values())))
breaks22_df
# breaks22_df[breaks22_df[0] > 0]
# Out:
#       0     1
# 0     0  1715
# 1     2   325
# 2     3    17
# 3     4   124
# 4     5    24
# 5     6    50
# 6     7    14
# 7     8    34
# 8     9    15
# 9    10    15
# 10   11    13
# 11   12    11
# 12   13     7
# 13   14     7
# 14   15     3
# 15   16     5
# 16   17     4
# 17   18     6
# 18   19     1
# 19   20     6
# 20   21     3
# 21   22     3
# 22   24     3
# 23   26     4
# 24   27     2
# 25   28     3
# 26   31     1
# 27   32     1
# 28   35     2
# 29   44     1
# 30   50     1
# 31   56     1
# 32   68     1
# 33   84     1
# 34  100     1
# 35  115     1
# 36  136     1
# 37  172     1
# 38  238     1

# %%
sns.scatterplot(data = breaks22_df[breaks22_df[0] > 0], x=0, y=1)
# Out:
# <AxesSubplot:xlabel='0', ylabel='1'>

# %%
od.keys()
# Out:
# dict_keys([6, 0, 2, 8, 28, 5, 4, 3, 22, 13, 7, 20, 11, 10, 12, 18, 14, 9, 26, 16, 15, 21, 32, 35, 27, 136, 56, 100, 31, 24, 238, 17, 84, 68, 44, 115, 19, 50, 172])

# %%
sns.countplot(data=chr22_df, x=cols[46])
# Out:
# <AxesSubplot:xlabel='Nb. breakpoints in chromosome', ylabel='count'>
